# %% [markdown]
# # Frozen Lake Experiment
# ### Import dependencies

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
from gym import wrappers, envs

import time, sys

# %% [markdown]
# ## Run Episodes

# %%
def run_episodes(environment, policy, gamma):
    state = environment.reset()[0]
    total_reward = 0
    step = 0
    win = 0
    done = False
    while not done:
        state, reward, done, _, __ = env.step(int(policy[state]))
        total_reward += (gamma ** step * reward)
        step += 1
        if done and reward == 1.0:
            win += 1
            break
    return total_reward, win

# %% [markdown]
# ## Policy Iteration

# %%
def policy_iteration(environment, gamma, max_iters = 200000):
    policy = np.random.choice(environment.action_space.n, size = environment.observation_space.n)
    desc = environment.unwrapped.desc
    for i in range(max_iters):
        old_policy_val_func = compute_value_function(environment, policy, gamma)
        new_policy = policy_extraction(environment, old_policy_val_func, gamma)
        if np.all(policy == new_policy):
            k = i + 1
            break
        policy = new_policy
    return policy, k

# %% [markdown]
# ## Policy Evaluation

# %%
def policy_evaluation(environment, policy, gamma, n = 100):
    wins = 0
    scores = []
    for i in range(n):
            score, win = run_episodes(environment, policy, gamma)
            scores.append(score)
            wins += win
    scores = [run_episodes(environment, policy, gamma) for _ in range(n)]
    return np.mean(scores), wins

# %% [markdown]
# ## Policy Extraction

# %%
def policy_extraction(environment, v, gamma):
    policy = np.zeros(environment.observation_space.n)
    for state in range(environment.observation_space.n):
        q_sa = np.zeros(environment.action_space.n)
        for action in range(environment.action_space.n):
            q_sa[action] = sum([p * (r + gamma * v[state_]) for p, state_, r, _ in environment.P[state][action]])
        policy[state] = np.argmax(q_sa)
    return policy

# %% [markdown]
# ## Compute Value Function

# %%
def compute_value_function(environment, policy, gamma):
    V = np.zeros(environment.observation_space.n)
    epsilon = 1e-05
    
    while True:
        prev_v = np.copy(V)
        for state in range(environment.observation_space.n):
            policy_action = policy[state]
            V[state] = sum([p * (r + gamma * prev_v[state_]) for p, state_, r, is_done, in environment.P[state][policy_action]])
        delta = np.sum(np.fabs(prev_v-V))
        if delta <= epsilon:
            break
    return V

# %% [markdown]
# ## Value Iteration

# %%
def value_iteration(environment, gamma, max_iters=100000):
    V = np.zeros(environment.observation_space.n)
    epsilon = 1e-20
#     desc = environment.unwrapped.desc
    for i in range(max_iters):
        prev_v = np.copy(V)
        for state in range(environment.observation_space.n):
            q_sa = [sum([p*(r + gamma*prev_v[state_]) for p, state_, r, _ in env.P[state][action]]) for action in range(environment.action_space.n)]
            V[state] = max(q_sa)
        delta = np.sum(np.fabs(prev_v-V))
        if delta <= epsilon:
            k = i + 1
            break
    return V, k

# %% [markdown]
# ## Begin Experiment

# %%
env = gym.make('FrozenLake-v1')
env = env.unwrapped
desc = env.unwrapped.desc

time_arr = [0] * 10
gamma_arr = [0] * 10
its = [0] * 10
scores_list = [0] * 10

# %% [markdown]
# ## Policy Iteration Analysis

# %%
n_episodes = 1000
for i in range(0,10):
    start = time.time()
    gamma = (i + 0.5) / 10
    
    best_policy, k = policy_iteration(env, gamma)
    policy_score, wins = policy_evaluation(env, best_policy, gamma, n=n_episodes)
    end = time.time()
    gamma_arr[i] = gamma
    scores_list[i] = policy_score
    its[i] = k
    time_arr[i] = end - start
    
    print(f'Summary (gamma = {gamma}):')
    print(f'Average wins over {n_episodes} episodes: {wins}')
    print(f'Average reward over {n_episodes} episodes: {policy_score}')
    print('-----------------------------------------------------------------------')
# Out:
# Summary (gamma = 0.05):
# Average wins over 1000 episodes: 199
# Average reward over 1000 episodes: 0.10350000048928981
# -----------------------------------------------------------------------
# Summary (gamma = 0.15):
# Average wins over 1000 episodes: 441
# Average reward over 1000 episodes: 0.21850018364917442
# -----------------------------------------------------------------------
# Summary (gamma = 0.25):
# Average wins over 1000 episodes: 441
# Average reward over 1000 episodes: 0.237001536708841
# -----------------------------------------------------------------------
# Summary (gamma = 0.35):
# Average wins over 1000 episodes: 447
# Average reward over 1000 episodes: 0.2270235926116316
# -----------------------------------------------------------------------
# Summary (gamma = 0.45):
# Average wins over 1000 episodes: 461
# Average reward over 1000 episodes: 0.23459504175817922
# -----------------------------------------------------------------------
# Summary (gamma = 0.55):
# Average wins over 1000 episodes: 437
# Average reward over 1000 episodes: 0.21220407605565633
# -----------------------------------------------------------------------
# Summary (gamma = 0.65):
# Average wins over 1000 episodes: 492
# Average reward over 1000 episodes: 0.22125354006855347
# -----------------------------------------------------------------------
# Summary (gamma = 0.75):
# Average wins over 1000 episodes: 448
# Average reward over 1000 episodes: 0.22823569841525768
# -----------------------------------------------------------------------
# Summary (gamma = 0.85):
# Average wins over 1000 episodes: 783
# Average reward over 1000 episodes: 0.40134565184082216
# -----------------------------------------------------------------------
# Summary (gamma = 0.95):
# Average wins over 1000 episodes: 788
# Average reward over 1000 episodes: 0.477322424788234
# -----------------------------------------------------------------------

# %%
plt.plot(gamma_arr, time_arr)
plt.xlabel('Gamma')
plt.ylabel('Execution Time (s)')
plt.title('Frozen Lake Policy Iteration: Execution Time Analysis')
plt.grid()
plt.savefig('FLPI time analysis ' + str(n_episodes) + 'ep.png')

# %%
plt.plot(gamma_arr, scores_list)
plt.xlabel('Gamma')
plt.ylabel('Average Rewards')
plt.title('Frozen Lake Policy Iteration: Reward Analysis')
plt.grid()
plt.savefig('FLPI reward analysis ' + str(n_episodes) + 'ep.png')

# %%
plt.plot(gamma_arr, its)
plt.xlabel('Gamma')
plt.ylabel('Iterations to Converge')
plt.title('Frozen Lake Policy Iteration: Convergence Analysis')
plt.grid()
plt.savefig('FLPI convergence analysis ' + str(n_episodes) + 'ep.png')

# %% [markdown]
# ## Value Iteration Analysis

# %%
best_vals = [0] * 10
n_episodes = 1000
for i in range(0,10):
    start = time.time()
    gamma = (i + 0.5) / 10
    best_value, k = value_iteration(env, gamma)
    policy = policy_extraction(env, best_value, gamma)
    policy_score, wins = policy_evaluation(env, policy, gamma, n=n_episodes)
    end = time.time()
    gamma_arr[i] = gamma
    its[i] = k
    best_vals[i] = best_value
    scores_list[i] = policy_score
    time_arr[i] = end-start
    
    print(f'Summary (gamma = {gamma}):')
    print(f'Average wins over {n_episodes} episodes: {wins}')
    print(f'Average reward over {n_episodes} episodes: {policy_score}')
    print('-----------------------------------------------------------------------')
# Out:
# Summary (gamma = 0.05):
# Average wins over 1000 episodes: 442
# Average reward over 1000 episodes: 0.22000000053491447
# -----------------------------------------------------------------------
# Summary (gamma = 0.15):
# Average wins over 1000 episodes: 473
# Average reward over 1000 episodes: 0.22850017932395092
# -----------------------------------------------------------------------
# Summary (gamma = 0.25):
# Average wins over 1000 episodes: 449
# Average reward over 1000 episodes: 0.23200177687246115
# -----------------------------------------------------------------------
# Summary (gamma = 0.35):
# Average wins over 1000 episodes: 438
# Average reward over 1000 episodes: 0.22552325159491415
# -----------------------------------------------------------------------
# Summary (gamma = 0.45):
# Average wins over 1000 episodes: 461
# Average reward over 1000 episodes: 0.22712463222672072
# -----------------------------------------------------------------------
# Summary (gamma = 0.55):
# Average wins over 1000 episodes: 445
# Average reward over 1000 episodes: 0.23935946543962677
# -----------------------------------------------------------------------
# Summary (gamma = 0.65):
# Average wins over 1000 episodes: 439
# Average reward over 1000 episodes: 0.22510712467407573
# -----------------------------------------------------------------------
# Summary (gamma = 0.75):
# Average wins over 1000 episodes: 454
# Average reward over 1000 episodes: 0.2275971480753744
# -----------------------------------------------------------------------
# Summary (gamma = 0.85):
# Average wins over 1000 episodes: 791
# Average reward over 1000 episodes: 0.39970731156792866
# -----------------------------------------------------------------------
# Summary (gamma = 0.95):
# Average wins over 1000 episodes: 773
# Average reward over 1000 episodes: 0.4805045179743123
# -----------------------------------------------------------------------

# %%
plt.plot(gamma_arr, time_arr)
plt.xlabel('Gamma')
plt.ylabel('Execution Time (s)')
plt.title('Frozen Lake Value Iteration: Execution Time Analysis')
plt.grid()
plt.savefig('FLVI time analysis ' + str(n_episodes) + 'ep.png')

# %%
plt.plot(gamma_arr, scores_list)
plt.xlabel('Gamma')
plt.ylabel('Average Rewards')
plt.title('Frozen Lake Value Iteration: Reward Analysis')
plt.grid()
plt.savefig('FLVI reward analysis ' + str(n_episodes) + 'ep.png')

# %%
plt.plot(gamma_arr, its)
plt.xlabel('Gamma')
plt.title('Frozen Lake Value Iteration: Convergence Analysis')
plt.grid()
plt.savefig('FLVI convergence analysis ' + str(n_episodes) + 'ep.png')

# %%
plt.plot(gamma_arr, best_vals)
plt.xlabel('Gamma')
plt.ylabel('Optimal Value')
plt.title('Frozen Lake Value Iteration: Best Value Analysis')
plt.grid()
plt.savefig('FLVI best value analysis ' + str(n_episodes) + 'ep.png')

# %% [markdown]
# ## Q-Learning Analysis

# %%
start = time.time()
reward_arr = []
its_arr = []
size_arr = []
chunks_arr = []
avgs_arr = []
time_arr = []
Q_arr = []
for i in range(0,10):
    epsilon = (i + 0.5) / 10
    print(f'Summary (ε={epsilon}): ')
    print(epsilon)
    Q = np.zeros((env.observation_space.n, env.action_space.n))
    rewards = []
    iters = []
    optimal = [0]*env.observation_space.n
    alpha = 0.85
    gamma = 0.95
    n_episodes = 30000
    win = 0
    env = gym.make('FrozenLake-v1')
    env = env.unwrapped
    desc = env.unwrapped.desc
    for episode in range(n_episodes):
        state = env.reset()[0]
        done = False
        t_reward = 0
        max_steps = 1000000
        for i in range(max_steps):
            if done:
                break
            current = state
            if np.random.rand() < epsilon:
                action = np.argmax(Q[current, :])
            else:
                action = env.action_space.sample()
            
            state, reward, done, info, _ = env.step(action)
            if reward == 1.0:
                win += 1
            t_reward += reward
            Q[current, action] += alpha * (reward + gamma * np.max(Q[state, :]) - Q[current, action])
        epsilon = (1-2.71**(-episode/1000))
        rewards.append(t_reward)
        iters.append(i)
    for state in range(env.observation_space.n):
        optimal[state] = np.argmax(Q[state, :])
    
    reward_arr.append(rewards)
    its_arr.append(iters)
    Q_arr.append(Q)
    
    env.close()
    end = time.time()
    time_arr.append(end-start)
    
    def chunk_list(rewards, size):
        for i in range(0, len(rewards), size):
            yield rewards[i:i+size]
    
    size = int(n_episodes / 50)
    chunks = list(chunk_list(rewards, size))
    avgs = [sum(chunk) / len(chunk) for chunk in chunks]
    size_arr.append(size)
    chunks_arr.append(chunks)
    avgs_arr.append(avgs)
    
    print(f'Wins over {n_episodes} episodes: {wins}')
    print(f'Average reward of {n_episodes} episodes: {np.mean(rewards)}')
    print(f'Wins over {n_episodes} episodes: {win}')
    print('-----------------------------------------------------------------------')
# Out:
# Summary (ε=0.05):
# 0.05
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.6852666666666667
# Wins over 30000 episodes: 20558
# -----------------------------------------------------------------------
# Summary (ε=0.15):
# 0.15
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.7040666666666666
# Wins over 30000 episodes: 21122
# -----------------------------------------------------------------------
# Summary (ε=0.25):
# 0.25
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.7131333333333333
# Wins over 30000 episodes: 21394
# -----------------------------------------------------------------------
# Summary (ε=0.35):
# 0.35
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.7025666666666667
# Wins over 30000 episodes: 21077
# -----------------------------------------------------------------------
# Summary (ε=0.45):
# 0.45
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.7035
# Wins over 30000 episodes: 21105
# -----------------------------------------------------------------------
# Summary (ε=0.55):
# 0.55
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.6876666666666666
# Wins over 30000 episodes: 20630
# -----------------------------------------------------------------------
# Summary (ε=0.65):
# 0.65
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.6972666666666667
# Wins over 30000 episodes: 20918
# -----------------------------------------------------------------------
# Summary (ε=0.75):
# 0.75
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.7059666666666666
# Wins over 30000 episodes: 21179
# -----------------------------------------------------------------------
# Summary (ε=0.85):
# 0.85
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.7076333333333333
# Wins over 30000 episodes: 21229
# -----------------------------------------------------------------------
# Summary (ε=0.95):
# 0.95
# Wins over 30000 episodes: 773
# Average reward of 30000 episodes: 0.7039
# Wins over 30000 episodes: 21117
# -----------------------------------------------------------------------

# %%
for i in range(0, 10):
    epsilon = (i + 0.5) / 10
    plt.plot(range(0, len(reward_arr[i]), size_arr[i]), avgs_arr[i], label='ε=' + str(epsilon))

plt.legend()
plt.xlabel('Iterations')
plt.ylabel('Average Reward')
plt.title('Frozen Lake Q-Learning: Constant ε Analysis')
plt.grid()
plt.savefig('FLQL constant eps.png')

# %%
epsilons = []
for i in range(0,10):
    epsilons.append((i + 0.5) / 10)
plt.plot(epsilons, time_arr)
plt.xlabel('ε Values')
plt.ylabel('Execution Time (s)')
plt.title('Frozen Lake Q-Learning: Execution Time Analysis')
plt.grid()
plt.savefig('FLQ time analysis.png')
